# %%
# !pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.13.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting regex (from tiktoken)
#   Downloading regex-2026.5.9-cp314-cp314-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting requests (from tiktoken)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting charset_normalizer<4,>=2 (from requests->tiktoken)
#   Using cached charset_normalizer-3.4.7-cp314-cp314-macosx_10_15_universal2.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests->tiktoken)
#   Downloading idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting urllib3<3,>=1.26 (from requests->tiktoken)
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests->tiktoken)
#   Downloading certifi-2026.5.20-py3-none-any.whl.metadata (2.5 kB)
# Downloading tiktoken-0.13.0-cp314-cp314-macosx_11_0_arm64.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.6/983.6 kB 23.6 MB/s  0:00:00
# Downloading regex-2026.5.9-cp314-cp314-macosx_11_0_arm64.whl (289 kB)
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached charset_normalizer-3.4.7-cp314-cp314-macosx_10_15_universal2.whl (309 kB)
# Downloading idna-3.18-py3-none-any.whl (65 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading certifi-2026.5.20-py3-none-any.whl (134 kB)
# Installing collected packages: urllib3, regex, idna, charset_normalizer, certifi, requests, tiktoken
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [tiktoken]
# Successfully installed certifi-2026.5.20 charset_normalizer-3.4.7 idna-3.18 regex-2026.5.9 requests-2.34.2 tiktoken-0.13.0 urllib3-2.7.0

# %%
from importlib.metadata import version

import tiktoken
print(f"tiktoken version: {version('tiktoken')}")
# Out:
# tiktoken version: 0.13.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

text = "Hello, how are you doing today? <|endoftext|> I hope you're having a great day!"

encoded = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
print(encoded)
# Out:
# [15496, 11, 703, 389, 345, 1804, 1909, 30, 220, 50256, 314, 2911, 345, 821, 1719, 257, 1049, 1110, 0]

# %%
decoded = tokenizer.decode(encoded)
print(decoded)
# Out:
# Hello, how are you doing today? <|endoftext|> I hope you're having a great day!

# %% [markdown]
# ## This image shows how the encode works and how the tokens are counted
# ![tiktoken.png](../tiktoken.png)
